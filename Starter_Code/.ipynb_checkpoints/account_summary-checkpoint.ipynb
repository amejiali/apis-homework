# %%
import os
import plaid
import requests
import datetime
import json
import pandas as pd
# %matplotlib inline

# %%
def pretty_print_response(response):
  print(json.dumps(response, indent=4, sort_keys=True))

# %%
PLAID_CLIENT_ID = os.getenv('PLAID_CLIENT_ID')
PLAID_SECRET = os.getenv('PLAID_SBX_SECRET_KEY')
PLAID_PUBLIC_KEY = os.getenv('PLAID_PUBLIC_KEY')
PLAID_ENV = os.getenv('PLAID_ENV', 'sandbox')
PLAID_PRODUCTS = os.getenv('PLAID_PRODUCTS', 'transactions')

# %% [markdown]
# # Plaid Access Token
#
# In this section, you will use the plaid-python api to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
# 1. Create a client to connect to plaid
# 2. Use the client to generate a public token and request the following items:
# ['transactions', 'income', 'assets']
# 3. Exchange the public token for an access token
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
INSTITUTION_ID = "ins_109508"

# %%
# YOUR CODE HERE
client = plaid.Client(client_id=PLAID_CLIENT_ID, secret=PLAID_SECRET, public_key=PLAID_PUBLIC_KEY, environment=PLAID_ENV)
#client = Client(client_id=PLAID_CLIENT_ID, secret=PLAID_SECRET, public_key=PLAID_PUBLIC_KEY, environment=PLAID_ENV)

client.Institutions.get(2)
# Out:
# {'institutions': [{'country_codes': ['CA'],
#    'credentials': [{'label': 'Login ID', 'name': 'username', 'type': 'text'},
#     {'label': 'Access Code (PAC)', 'name': 'password', 'type': 'password'}],
#    'has_mfa': True,
#    'input_spec': 'fixed',
#    'institution_id': 'ins_118841',
#    'mfa': ['code', 'list', 'questions', 'selections'],
#    'mfa_code_type': 'numeric',
#    'name': 'Access Credit Union - Online Banking',
#    'products': ['assets', 'balance', 'transactions', 'income', 'identity'],
#    'routing_numbers': []},
#   {'country_codes': ['GB'],
#    'credentials': [{'label': 'Username', 'name': 'username', 'type': 'text'},
#     {'label': 'Password', 'name': 'password', 'type': 'password'}],
#    'has_mfa': True,
#    'input_spec': 'fixed',
#    'institution_id': 'ins_119371',
#    'mfa': ['code', 'list', 'questions', 'selections'],
#    'mfa_code_type': 'numeric',
#    'name': 'Aegon (Online Services)',
#    'products': ['assets', 'balance', 'transactions', 'investments'],
#    'routing_numbers': []}],
#  'request_id': 'c4N3Tx4oxc6jVc9',
#  'total': 11244}

# %% [markdown]
# ### 2. Generate a public token

# %%
# YOUR CODE HERE
create_tkn_response = client.Sandbox.public_token.create(INSTITUTION_ID, ['transactions','income','assets'])

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# YOUR CODE HERE
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])
access_token = exchange_response['access_token']

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# YOUR CODE HERE
accounts = client.Accounts.get(access_token)

#Iterate in accounts
i = 0
for i in range (0, len(accounts['accounts'])):
    pretty_print_response(accounts['accounts'][i]['account_id'])
    #print(f"Account_ID_{i+1} : {accounts['accounts'][i]['account_id']}")
    i+=1
# Out:
# "DQjD5XnqNyhEJvnRKenVSLqgVjxnJBcvDRo8Z"
# "VKGD5JZLnkty8pv9DevgIKyQLJdx1btW1yVJl"
# "wr9mjZRlLQhGAMB451BZIpR4ZPleB6CrwRp6K"
# "5qGmg8nbDyFRpMQKPnQmSApoVZ5L7mtZlynDL"
# "JoRD5XwxZBtDqNWQ9rWmt5KD9X1WgBTd3MyLW"
# "kgjWqBMDdzF6gkR7qxRdH9RelmV8jbcWnDjb4"
# "l85nK3mDaBTGBbyNKdygI49vVqnbZriZQgqvD"
# "qnpyxkJD74UWZPyzxJyAIERm1bxAaqhdGPjqp"

# %% [markdown]
# ---

# %% [markdown]
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
# 2. Print the categories for each transaction type
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# YOUR CODE HERE
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now())
transaction_response = client.Transactions.get(access_token,start_date,end_date)
#transaction_response

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# YOUR CODE HERE
#pretty_print_response(transaction_response['transactions'][1]['category'])

print("Transaction ID                           Category")
print("---------------------------------------------------------------------------------------")
for transactions in transaction_response['transactions']:
    print(f"{transactions['transaction_id']}    {transactions['category']}")
# Out:
# Transaction ID                           Category
# ---------------------------------------------------------------------------------------
# 7r3DEkRbwyhvmPZW7gZoSaPG5M7b7WSg9gV3z    ['Payment', 'Credit Card']
# dQa65bMXq7hkj58qxn8KhGVk4WgAgLIZWZA9b    ['Travel', 'Car Service', 'Ride Share']
# g1ZW5qMXzlFEKMag4AaySGJBjwZkZPIgmgk9P    ['Transfer', 'Debit']
# QngD5ypM8PUe8EdyAvdrI3kyE1PAPVHp8pABk    ['Transfer', 'Deposit']
# Z3DW5REM9zskwa1MAv1phdDZl3KkKatgKgkWg    ['Recreation', 'Gyms and Fitness Centers']
# ajyb5D6XwNhKmEejzWepUdX3x7NGNzt7W7Gna    ['Travel', 'Airlines and Aviation Services']
# 4lj5omnbXyI5j6xqNZxdUEN49QMrMefd1dEW5    ['Food and Drink', 'Restaurants']
# NWbD5X8NpaSwZLKmPxKEhkAGmeyNy3tWDWNad    ['Food and Drink', 'Restaurants', 'Coffee Shop']
# PGXD5VkWgNcbvdJ8MaJpFvoxG1NmNZf7M7mjR    ['Food and Drink', 'Restaurants']
# eZQW5nMXKeTGkMyKdJylIr1oNPKnKmtLjLnPy    ['Transfer', 'Credit']
# MkGD5Xg4LdF9n46xN36zHyvEbLqZqzh9M9ZkL    ['Travel', 'Airlines and Aviation Services']
# joXnlzL5xrt9Bx5JDe51HGxkq6wgw9I1X1b9j    ['Travel', 'Car Service', 'Ride Share']
# 1n3E186Vv7U7wMdnXLd6SAywl8p7pxh5J5vVq    ['Food and Drink', 'Restaurants']
# oANnBa1DPdiGKPoMBmo9IjAyvKBnB5fRlRwAr    ['Payment']
# pGpn34MDjkcErMeN3AegSyknvjKNK6hL1LmeK    ['Food and Drink', 'Restaurants']
# L8yD5Xpa1xTbENDvMBDXFaJx3XNzN1SPrPzBl    ['Shops', 'Sporting Goods']
# QngD5ypM8PUe8EdyAvdrI3kNRJ5ByofpX6gwg    ['Payment', 'Credit Card']
# AjbERXwVdyhKep187J15UQGXjgeAZws1DJp1v    ['Travel', 'Car Service', 'Ride Share']
# PGXD5VkWgNcbvdJ8MaJpFvoXzW9bxdc7a5eJX    ['Transfer', 'Debit']
# wr9mjZRlLQhGAMB451BZIpRawvZmJbfrwRpPe    ['Transfer', 'Deposit']
# yBzne1kKoJh9mRgM3ng7HVmJgoGkxztymna5X    ['Recreation', 'Gyms and Fitness Centers']
# WrgD5nXMbqhkWDG3AQG8hKrPoX7WbAfl8yblk    ['Travel', 'Airlines and Aviation Services']
# 8zVEkXJm5yhwAkRaG9RLhbm81X9jyJfw6pXw3    ['Food and Drink', 'Restaurants']
# EZED5XVKPlTk8oKpNAK7haplGj1ZPBIX7eBXn    ['Food and Drink', 'Restaurants', 'Coffee Shop']
# g1ZW5qMXzlFEKMag4AaySGJ3revyBoigBR6gR    ['Food and Drink', 'Restaurants']
# eZQW5nMXKeTGkMyKdJylIr1lQW4vo3uLQBbrg    ['Transfer', 'Credit']
# mEZnkxMD43tElxB3kaBZSGglA8ka1DiLNpoPz    ['Travel', 'Airlines and Aviation Services']
# oANnBa1DPdiGKPoMBmo9IjAPD98LydcRD5ZRQ    ['Travel', 'Car Service', 'Ride Share']
# b7QWJnDX5PfGgka6BAaZIlkojWX14ZfVjKkz1    ['Food and Drink', 'Restaurants']
# nW1nzdRDNxSGq9xVz4xXIPLXR9ldoju6RV5En    ['Payment']
# G1BD5Xnz7KFKE1NjQlNzU31GeXoKwaf1vxp8k    ['Food and Drink', 'Restaurants']
# AjbERXwVdyhKep187J15UQGXjgeAZws1DJpyZ    ['Shops', 'Sporting Goods']
# 7r3DEkRbwyhvmPZW7gZoSaPXVeJzGrIgPy5dW    ['Payment', 'Credit Card']
# pGpn34MDjkcErMeN3AegSykq7XlbnZILGjvLQ    ['Travel', 'Car Service', 'Ride Share']
# NWbD5X8NpaSwZLKmPxKEhkAXrLqoGZiWdpGxy    ['Transfer', 'Debit']
# VKGD5JZLnkty8pv9DevgIKyqDWL9VkfW1yV9G    ['Transfer', 'Deposit']
# WrgD5nXMbqhkWDG3AQG8hKrPoX7WbAfl8ybvp    ['Recreation', 'Gyms and Fitness Centers']
# L8yD5Xpa1xTbENDvMBDXFaJevEGbx8IPMKxPE    ['Travel', 'Airlines and Aviation Services']
# MkGD5Xg4LdF9n46xN36zHyv4nm19ExI9vpW9P    ['Food and Drink', 'Restaurants']
# 1n3E186Vv7U7wMdnXLd6SAy6KaQ5wji5RXk5o    ['Food and Drink', 'Restaurants', 'Coffee Shop']
# Z3DW5REM9zskwa1MAv1phdD9qWBVZLfgpmEgV    ['Food and Drink', 'Restaurants']
# joXnlzL5xrt9Bx5JDe51HGxjdzVnkEi1dm76X    ['Transfer', 'Credit']
# EZED5XVKPlTk8oKpNAK7haplGj1ZPBIX7eBED    ['Travel', 'Airlines and Aviation Services']
# QngD5ypM8PUe8EdyAvdrI3kNRJ5ByofpX6gpW    ['Travel', 'Car Service', 'Ride Share']
# 8zVEkXJm5yhwAkRaG9RLhbm81X9jyJfw6pXrD    ['Food and Drink', 'Restaurants']
# g1ZW5qMXzlFEKMag4AaySGJ3revyBoigBR6Mv    ['Payment']
# oANnBa1DPdiGKPoMBmo9IjAPD98LydcRD5ZKJ    ['Food and Drink', 'Restaurants']
# pGpn34MDjkcErMeN3AegSykq7XlbnZILGjvKy    ['Shops', 'Sporting Goods']

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: date, name, amount, category.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# YOUR CODE HERE
transactions = transaction_response['transactions']
data_df = pd.DataFrame(transactions)[['date', 'name', 'amount', 'category']]
data_df
# Out:
#           date                                   name   amount  \
# 0   2020-01-16           CREDIT CARD 3333 PAYMENT *//    25.00
# 1   2020-01-16                 Uber 063015 SF**POOL**     5.40
# 2   2020-01-15  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 3   2020-01-15                   CD DEPOSIT .INITIAL.  1000.00
# 4   2020-01-14                    Touchstone Climbing    78.50
# 5   2020-01-14                        United Airlines  -500.00
# 6   2020-01-13                             McDonald's    12.00
# 7   2020-01-13                              Starbucks     4.33
# 8   2020-01-12                               SparkFun    89.40
# 9   2020-01-11                           INTRST PYMNT    -4.22
# 10  2020-01-01                        United Airlines   500.00
# 11  2019-12-30                 Uber 072515 SF**POOL**     6.33
# 12  2019-12-27                             Tectra Inc   500.00
# 13  2019-12-26              AUTOMATIC PAYMENT - THANK  2078.50
# 14  2019-12-26                                    KFC   500.00
# 15  2019-12-26                   Madison Bicycle Shop   500.00
# 16  2019-12-17           CREDIT CARD 3333 PAYMENT *//    25.00
# 17  2019-12-17                 Uber 063015 SF**POOL**     5.40
# 18  2019-12-16  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 19  2019-12-16                   CD DEPOSIT .INITIAL.  1000.00
# 20  2019-12-15                    Touchstone Climbing    78.50
# 21  2019-12-15                        United Airlines  -500.00
# 22  2019-12-14                             McDonald's    12.00
# 23  2019-12-14                              Starbucks     4.33
# 24  2019-12-13                               SparkFun    89.40
# 25  2019-12-12                           INTRST PYMNT    -4.22
# 26  2019-12-02                        United Airlines   500.00
# 27  2019-11-30                 Uber 072515 SF**POOL**     6.33
# 28  2019-11-27                             Tectra Inc   500.00
# 29  2019-11-26              AUTOMATIC PAYMENT - THANK  2078.50
# 30  2019-11-26                                    KFC   500.00
# 31  2019-11-26                   Madison Bicycle Shop   500.00
# 32  2019-11-17           CREDIT CARD 3333 PAYMENT *//    25.00
# 33  2019-11-17                 Uber 063015 SF**POOL**     5.40
# 34  2019-11-16  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 35  2019-11-16                   CD DEPOSIT .INITIAL.  1000.00
# 36  2019-11-15                    Touchstone Climbing    78.50
# 37  2019-11-15                        United Airlines  -500.00
# 38  2019-11-14                             McDonald's    12.00
# 39  2019-11-14                              Starbucks     4.33
# 40  2019-11-13                               SparkFun    89.40
# 41  2019-11-12                           INTRST PYMNT    -4.22
# 42  2019-11-02                        United Airlines   500.00
# 43  2019-10-31                 Uber 072515 SF**POOL**     6.33
# 44  2019-10-28                             Tectra Inc   500.00
# 45  2019-10-27              AUTOMATIC PAYMENT - THANK  2078.50
# 46  2019-10-27                                    KFC   500.00
# 47  2019-10-27                   Madison Bicycle Shop   500.00
#
#                                       category
# 0                       [Payment, Credit Card]
# 1            [Travel, Car Service, Ride Share]
# 2                            [Transfer, Debit]
# 3                          [Transfer, Deposit]
# 4       [Recreation, Gyms and Fitness Centers]
# 5     [Travel, Airlines and Aviation Services]
# 6                [Food and Drink, Restaurants]
# 7   [Food and Drink, Restaurants, Coffee Shop]
# 8                [Food and Drink, Restaurants]
# 9                           [Transfer, Credit]
# 10    [Travel, Airlines and Aviation Services]
# 11           [Travel, Car Service, Ride Share]
# 12               [Food and Drink, Restaurants]
# 13                                   [Payment]
# 14               [Food and Drink, Restaurants]
# 15                     [Shops, Sporting Goods]
# 16                      [Payment, Credit Card]
# 17           [Travel, Car Service, Ride Share]
# 18                           [Transfer, Debit]
# 19                         [Transfer, Deposit]
# 20      [Recreation, Gyms and Fitness Centers]
# 21    [Travel, Airlines and Aviation Services]
# 22               [Food and Drink, Restaurants]
# 23  [Food and Drink, Restaurants, Coffee Shop]
# 24               [Food and Drink, Restaurants]
# 25                          [Transfer, Credit]
# 26    [Travel, Airlines and Aviation Services]
# 27           [Travel, Car Service, Ride Share]
# 28               [Food and Drink, Restaurants]
# 29                                   [Payment]
# 30               [Food and Drink, Restaurants]
# 31                     [Shops, Sporting Goods]
# 32                      [Payment, Credit Card]
# 33           [Travel, Car Service, Ride Share]
# 34                           [Transfer, Debit]
# 35                         [Transfer, Deposit]
# 36      [Recreation, Gyms and Fitness Centers]
# 37    [Travel, Airlines and Aviation Services]
# 38               [Food and Drink, Restaurants]
# 39  [Food and Drink, Restaurants, Coffee Shop]
# 40               [Food and Drink, Restaurants]
# 41                          [Transfer, Credit]
# 42    [Travel, Airlines and Aviation Services]
# 43           [Travel, Car Service, Ride Share]
# 44               [Food and Drink, Restaurants]
# 45                                   [Payment]
# 46               [Food and Drink, Restaurants]
# 47                     [Shops, Sporting Goods]

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# YOUR CODE HERE

data_df['amount'] = data_df['amount'].astype('float')
data_df["date"] = pd.DatetimeIndex(data_df["date"])
data_df.set_index("date", inplace=True)

data_df['category']=data_df.category.apply(', '.join)
#data_df.dtypes
data_df
# Out:
#                                              name   amount  \
# date
# 2020-01-16           CREDIT CARD 3333 PAYMENT *//    25.00
# 2020-01-16                 Uber 063015 SF**POOL**     5.40
# 2020-01-15  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 2020-01-15                   CD DEPOSIT .INITIAL.  1000.00
# 2020-01-14                    Touchstone Climbing    78.50
# 2020-01-14                        United Airlines  -500.00
# 2020-01-13                             McDonald's    12.00
# 2020-01-13                              Starbucks     4.33
# 2020-01-12                               SparkFun    89.40
# 2020-01-11                           INTRST PYMNT    -4.22
# 2020-01-01                        United Airlines   500.00
# 2019-12-30                 Uber 072515 SF**POOL**     6.33
# 2019-12-27                             Tectra Inc   500.00
# 2019-12-26              AUTOMATIC PAYMENT - THANK  2078.50
# 2019-12-26                                    KFC   500.00
# 2019-12-26                   Madison Bicycle Shop   500.00
# 2019-12-17           CREDIT CARD 3333 PAYMENT *//    25.00
# 2019-12-17                 Uber 063015 SF**POOL**     5.40
# 2019-12-16  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 2019-12-16                   CD DEPOSIT .INITIAL.  1000.00
# 2019-12-15                    Touchstone Climbing    78.50
# 2019-12-15                        United Airlines  -500.00
# 2019-12-14                             McDonald's    12.00
# 2019-12-14                              Starbucks     4.33
# 2019-12-13                               SparkFun    89.40
# 2019-12-12                           INTRST PYMNT    -4.22
# 2019-12-02                        United Airlines   500.00
# 2019-11-30                 Uber 072515 SF**POOL**     6.33
# 2019-11-27                             Tectra Inc   500.00
# 2019-11-26              AUTOMATIC PAYMENT - THANK  2078.50
# 2019-11-26                                    KFC   500.00
# 2019-11-26                   Madison Bicycle Shop   500.00
# 2019-11-17           CREDIT CARD 3333 PAYMENT *//    25.00
# 2019-11-17                 Uber 063015 SF**POOL**     5.40
# 2019-11-16  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 2019-11-16                   CD DEPOSIT .INITIAL.  1000.00
# 2019-11-15                    Touchstone Climbing    78.50
# 2019-11-15                        United Airlines  -500.00
# 2019-11-14                             McDonald's    12.00
# 2019-11-14                              Starbucks     4.33
# 2019-11-13                               SparkFun    89.40
# 2019-11-12                           INTRST PYMNT    -4.22
# 2019-11-02                        United Airlines   500.00
# 2019-10-31                 Uber 072515 SF**POOL**     6.33
# 2019-10-28                             Tectra Inc   500.00
# 2019-10-27              AUTOMATIC PAYMENT - THANK  2078.50
# 2019-10-27                                    KFC   500.00
# 2019-10-27                   Madison Bicycle Shop   500.00
#
#                                             category
# date
# 2020-01-16                      Payment, Credit Card
# 2020-01-16           Travel, Car Service, Ride Share
# 2020-01-15                           Transfer, Debit
# 2020-01-15                         Transfer, Deposit
# 2020-01-14      Recreation, Gyms and Fitness Centers
# 2020-01-14    Travel, Airlines and Aviation Services
# 2020-01-13               Food and Drink, Restaurants
# 2020-01-13  Food and Drink, Restaurants, Coffee Shop
# 2020-01-12               Food and Drink, Restaurants
# 2020-01-11                          Transfer, Credit
# 2020-01-01    Travel, Airlines and Aviation Services
# 2019-12-30           Travel, Car Service, Ride Share
# 2019-12-27               Food and Drink, Restaurants
# 2019-12-26                                   Payment
# 2019-12-26               Food and Drink, Restaurants
# 2019-12-26                     Shops, Sporting Goods
# 2019-12-17                      Payment, Credit Card
# 2019-12-17           Travel, Car Service, Ride Share
# 2019-12-16                           Transfer, Debit
# 2019-12-16                         Transfer, Deposit
# 2019-12-15      Recreation, Gyms and Fitness Centers
# 2019-12-15    Travel, Airlines and Aviation Services
# 2019-12-14               Food and Drink, Restaurants
# 2019-12-14  Food and Drink, Restaurants, Coffee Shop
# 2019-12-13               Food and Drink, Restaurants
# 2019-12-12                          Transfer, Credit
# 2019-12-02    Travel, Airlines and Aviation Services
# 2019-11-30           Travel, Car Service, Ride Share
# 2019-11-27               Food and Drink, Restaurants
# 2019-11-26                                   Payment
# 2019-11-26               Food and Drink, Restaurants
# 2019-11-26                     Shops, Sporting Goods
# 2019-11-17                      Payment, Credit Card
# 2019-11-17           Travel, Car Service, Ride Share
# 2019-11-16                           Transfer, Debit
# 2019-11-16                         Transfer, Deposit
# 2019-11-15      Recreation, Gyms and Fitness Centers
# 2019-11-15    Travel, Airlines and Aviation Services
# 2019-11-14               Food and Drink, Restaurants
# 2019-11-14  Food and Drink, Restaurants, Coffee Shop
# 2019-11-13               Food and Drink, Restaurants
# 2019-11-12                          Transfer, Credit
# 2019-11-02    Travel, Airlines and Aviation Services
# 2019-10-31           Travel, Car Service, Ride Share
# 2019-10-28               Food and Drink, Restaurants
# 2019-10-27                                   Payment
# 2019-10-27               Food and Drink, Restaurants
# 2019-10-27                     Shops, Sporting Goods

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
# 1. Determine the previous year's gross income and print the results
# 2. Determine the current monthly income and print the results
# 3. Determine the projected yearly income and print the results

# %%
# YOUR CODE HERE
income = client.Income.get(access_token)['income']

gross_income =income['last_year_income_before_tax']
monthly_income = income['income_streams'][0]['monthly_income']
projected_income = income['projected_yearly_income_before_tax']

print(f'Last Year Gross Income  : {gross_income}')
print(f'Current Monthly Income  : {monthly_income}')
print(f'Projected Yearly Income : {projected_income}')

#income
# Out:
# Last Year Gross Income  : 7285
# Current Monthly Income  : 500
# Projected Yearly Income : 7389

# %% [markdown]
# ---

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
# 2. Generate a bar chart with the number of transactions for each category
# 3. Calculate the expenses per month
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
# YOUR CODE HERE
df=data_df.groupby('category').sum().abs().reset_index()
df.plot(kind='pie', y = 'amount', autopct='%1.1f%%', startangle=90, shadow=False, labels=df['category'], legend = False, fontsize=7, figsize=(10,10))

# %%
df
# Out:
#                                     category    amount
# 0                Food and Drink, Restaurants   3304.20
# 1   Food and Drink, Restaurants, Coffee Shop     12.99
# 2                                    Payment   6235.50
# 3                       Payment, Credit Card     75.00
# 4       Recreation, Gyms and Fitness Centers    235.50
# 5                      Shops, Sporting Goods   1500.00
# 6                           Transfer, Credit     12.66
# 7                            Transfer, Debit  17550.00
# 8                          Transfer, Deposit   3000.00
# 9     Travel, Airlines and Aviation Services      0.00
# 10           Travel, Car Service, Ride Share     35.19

# %% [markdown]
# ### Calculate the expenses per month

# %%
# YOUR CODE HERE
monthly_expenses = data_df.groupby(by=[data_df.index.month, data_df.index.year]).sum()
monthly_expenses
# Out:
#              amount
# date date
# 1    2020   7060.41
# 10   2019   3584.83
# 11   2019  10645.24
# 12   2019  10645.24
